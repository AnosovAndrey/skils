# %% [markdown]
# <a href="https://colab.research.google.com/github/AnosovAndrey/skils/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#---- ЗАГРУЗКА БИБЛИОТЕК ----
import numpy as np
import pandas as pd
import os 

#выбор рабочей папки и данных
folder="""../content/"""
os.chdir(folder)
table="""dataset.xlsx"""
sheet='Лист1'

#---- ЗАГРУЗКА ДАННЫХ ----
dataset=pd.read_excel(table,sheet_name=sheet, header = None)
print(dataset.head())
print("Число ",len(np.array(dataset)))
#dataset['Y'].unique()#определяем количество уникальных типов
# Out:
#                                                   0   ...   31
# 0  Разработка компьютерных игр и мультимедийных п...  ...  NaN
# 1            Разработка мобильных приложений(юниоры)  ...  NaN
# 2                     Преподавание в младших классах  ...  NaN
# 3                      Дошкольное воспитание(юниоры)  ...  NaN
# 4                              Дошкольное воспитание  ...  NaN
#
# [5 rows x 32 columns]
# Число  130

# %%
dataset = np.array(dataset.transpose())
print(dataset[0])
# print(len(list(filter(, dataset[0][0]))))
# print(dataset[0])
# Out:
# ['Разработка компьютерных игр и мультимедийных приложений'
#  'Разработка компьютерных игр и мультимедийных приложений – процесс создания компьютерных программ, направленных на развлечение, обучение пользователя, а также создание информационных интерактивных приложений. Игры и мультимедийные приложения относятся к классу программных систем высокой сложности. Разработка их требует высокой квалификации. Проектирование игр, как программных систем, требует умений анализа требований к программной системе, навыков программирования, особенностей технических средств и сред разработки. Кроме того, реализация компьютерных игр требует алгоритмических умений и навыков, проектирования и разработки интерактивных приложений, двумерной и трехмерной компьютерной графики, кроссплатформенном программировании и т.д. В процесс разработки входит анализ и постановка задачи, разработка игровых объектов и анимации, настройка физики и методов взаимодействия пользователя с игровыми объектами, построение игровых уровней, построение интерфейса пользователя, отладка и тестирование проекта. '
#  'Организация и управление работой' 13
#  'Специалист должен знать и понимать: • Принципы и навыки, обеспечивающие продуктивную работу; • Преимущества использования современных средств разработки;                                                    Специалист должен уметь: • Использовать предоставленные ресурсы для продуктивной работы; • Применять исследовательские технологии и навыки, чтобы иметь представление о самых последних отраслевых рекомендациях; • Анализировать результаты собственной деятельности в сравнении с ожиданиями и потребностями клиента и организации. '
#  'Программирование на языке С#' 27
#  'Специалист должен знать и понимать: • Базовые алгоритмы программирования • Структуры данных • Объектно-ориентированное программирование • Событийно-ориентированное программировани Специалист должен уметь: • пользоваться Visual Studio • пользоваться MonoDevelop • Реализовать алгоритмы на языке программирования C# '
#  'Unity 3D' 30
#  'Специалист должен знать и понимать: • Основные принципы и понятия разработки игр • Технологию работы с объектами на сцене  • Компоненты объектов • Настройку игровых объектов и их компонентов Специалист должен уметь: • Работать со сценами • Уметь верстать игровые сцены • Работать с компонентами объект'
#  'Оптимизация компьютерных игр и приложений' 10
#  'Специалист должен знать и понимать: • Особенности оптимизации компьютерных игр и приложений для ПК и мобильных устройств • Архитектуру мобильных устройств в контексте оптимизации приложений Специалист должен уметь: • Оптимизировать текстуры и материалы для целевых платформ • Оптимизировать основной процесс приложения • Оптимизировать использование физики в компьютерных играх и приложений • Умение использовать встроенные в игровые движки внутренние и внешние профайлеры '
#  'Анализ и проектирование ' 15
#  'Специалист должен знать и понимать: • Важность принятия во внимание всех возможных вариантов и выработки оптимального решения на основе здравого аналитического суждения и с учетом интересов клиента; • Важность использования методологий системного анализа и проектирования; • Необходимость следить за новыми технологиями и принимать решение относительно уместности их применения; • Важность оптимизации проекта системы с упором на модульность и возможность повторного использования. Специалист должен уметь: • Проектировать приложение при помощи: • макета приложения и переходов; • схемы класса, схемы последовательности, схемы состояния, схемы деятельности; • проектирования человеко-машинного интерфейса; • проектирования многоуровневого приложения. '
#  'Публикация' 5.0
#  'Специалист должен знать и понимать: • Особенности сборки приложения под разные ОС(Windows, Android, IOS) • Специалист должен уметь: правильно собрать «билд» приложения, • запустить «билд» на устройстве, • продемонстрировать работоспособность приложения '
#  nan nan nan nan nan nan nan nan nan nan nan nan]

# %%
i = 0
new_dataset = []
for line in np.array(dataset):
  line = line[~pd.isnull(line)]
  total = ''
  for j in range((int)((len(line) - 2)/3)):
    total += str(line[4 + j*3]) + " "
  for j in range((int)((len(line) - 2)/3)):
    new_dataset.insert(i, [line[0], line[1], line[2 + j*3], line[3 + j*3], line[4 + j*3], total])
    i += 1
print(len(new_dataset))
#print(new_dataset.head())
# new_dataset[i] = np.array(line[0], line[1])
# Out:
# 823

# %%
A=pd.DataFrame(new_dataset,columns=["компетения","описание компетенции", "группа навыков", "вес группы навыков", "описание группы навыков", "все группы навыков"])
A.to_excel('new.xlsx')

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
stop_words=["как","от","его","или","and", '06', '10', '11', '12', '13', 
            '14', '15', '17', '27', '28', "для", "при", "по", "на", "их", "он", 
            "за", "20", "должен", "специалист", "понимать", "знать","работа",
            "это", "работы" 
]

# %%
all_groups = np.array(new_dataset)[0:,5:6]
all_groups = all_groups.flatten().tolist()

cv = CountVectorizer(all_groups, max_df=0.8, min_df=25, stop_words=stop_words) #max_df=0.8
count_vector=cv.fit_transform(all_groups)

# %%
print(all_groups[0])
# Out:
# Специалист должен знать и понимать: • Принципы и навыки, обеспечивающие продуктивную работу; • Преимущества использования современных средств разработки;                                                    Специалист должен уметь: • Использовать предоставленные ресурсы для продуктивной работы; • Применять исследовательские технологии и навыки, чтобы иметь представление о самых последних отраслевых рекомендациях; • Анализировать результаты собственной деятельности в сравнении с ожиданиями и потребностями клиента и организации.  Специалист должен знать и понимать: • Базовые алгоритмы программирования • Структуры данных • Объектно-ориентированное программирование • Событийно-ориентированное программировани Специалист должен уметь: • пользоваться Visual Studio • пользоваться MonoDevelop • Реализовать алгоритмы на языке программирования C#  Специалист должен знать и понимать: • Основные принципы и понятия разработки игр • Технологию работы с объектами на сцене  • Компоненты объектов • Настройку игровых объектов и их компонентов Специалист должен уметь: • Работать со сценами • Уметь верстать игровые сцены • Работать с компонентами объект Специалист должен знать и понимать: • Особенности оптимизации компьютерных игр и приложений для ПК и мобильных устройств • Архитектуру мобильных устройств в контексте оптимизации приложений Специалист должен уметь: • Оптимизировать текстуры и материалы для целевых платформ • Оптимизировать основной процесс приложения • Оптимизировать использование физики в компьютерных играх и приложений • Умение использовать встроенные в игровые движки внутренние и внешние профайлеры  Специалист должен знать и понимать: • Важность принятия во внимание всех возможных вариантов и выработки оптимального решения на основе здравого аналитического суждения и с учетом интересов клиента; • Важность использования методологий системного анализа и проектирования; • Необходимость следить за новыми технологиями и принимать решение относительно уместности их применения; • Важность оптимизации проекта системы с упором на модульность и возможность повторного использования. Специалист должен уметь: • Проектировать приложение при помощи: • макета приложения и переходов; • схемы класса, схемы последовательности, схемы состояния, схемы деятельности; • проектирования человеко-машинного интерфейса; • проектирования многоуровневого приложения.  Специалист должен знать и понимать: • Особенности сборки приложения под разные ОС(Windows, Android, IOS) • Специалист должен уметь: правильно собрать «билд» приложения, • запустить «билд» на устройстве, • продемонстрировать работоспособность приложения

# %%
print(count_vector.shape)
print(cv.vocabulary_)
# Out:
# (823, 2243)
# {'навыки': 777, 'обеспечивающие': 864, 'продуктивную': 1371, 'работу': 1456, 'преимущества': 1289, 'использования': 521, 'современных': 1717, 'средств': 1801, 'разработки': 1497, 'уметь': 1994, 'использовать': 523, 'предоставленные': 1272, 'ресурсы': 1570, 'продуктивной': 1370, 'применять': 1317, 'исследовательские': 535, 'технологии': 1920, 'чтобы': 2173, 'иметь': 474, 'представление': 1283, 'последних': 1210, 'отраслевых': 1032, 'анализировать': 35, 'результаты': 1555, 'собственной': 1711, 'деятельности': 308, 'сравнении': 1798, 'ожиданиями': 937, 'потребностями': 1232, 'клиента': 581, 'организации': 977, 'базовые': 56, 'алгоритмы': 29, 'программирования': 1353, 'структуры': 1849, 'данных': 284, 'объектно': 921, 'программирование': 1352, 'пользоваться': 1190, 'языке': 2240, 'основные': 995, 'понятия': 1199, 'технологию': 1926, 'объектами': 919, 'компоненты': 614, 'объектов': 922, 'настройку': 807, 'игровых': 440, 'компонентов': 613, 'работать': 1451, 'со': 1702, 'игровые': 439, 'особенности': 1000, 'оптимизации': 971, 'компьютерных': 619, 'приложений': 1307, 'пк': 1099, 'мобильных': 750, 'устройств': 2037, 'архитектуру': 46, 'контексте': 636, 'оптимизировать': 972, 'текстуры': 1883, 'материалы': 705, 'целевых': 2123, 'платформ': 1111, 'основной': 993, 'процесс': 1438, 'приложения': 1308, 'использование': 517, 'физики': 2062, 'умение': 1992, 'встроенные': 202, 'внутренние': 156, 'внешние': 148, 'важность': 97, 'принятия': 1327, 'во': 159, 'внимание': 151, 'всех': 199, 'возможных': 172, 'вариантов': 100, 'выработки': 225, 'оптимального': 967, 'решения': 1578, 'основе': 991, 'аналитического': 38, 'суждения': 1854, 'учетом': 2053, 'интересов': 500, 'методологий': 731, 'системного': 1669, 'анализа': 34, 'проектирования': 1382, 'необходимость': 832, 'следить': 1679, 'принимать': 1320, 'решение': 1574, 'относительно': 1022, 'применения': 1312, 'проекта': 1377, 'системы': 1674, 'возможность': 169, 'повторного': 1128, 'проектировать': 1383, 'приложение': 1306, 'помощи': 1194, 'макета': 683, 'схемы': 1866, 'класса': 576, 'последовательности': 1213, 'состояния': 1761, 'человеко': 2149, 'машинного': 707, 'интерфейса': 504, 'многоуровневого': 748, 'сборки': 1616, 'под': 1130, 'разные': 1488, 'правильно': 1242, 'собрать': 1709, 'продемонстрировать': 1366, 'работоспособность': 1455, 'командной': 598, 'общие': 917, 'типы': 1935, 'проблем': 1338, 'которые': 654, 'могут': 751, 'возникнуть': 176, 'разработке': 1496, 'программного': 1354, 'обеспечения': 862, 'коммерческой': 603, 'диагностические': 311, 'подходы': 1155, 'решению': 1577, 'тенденции': 1891, 'отрасли': 1033, 'включая': 135, 'новые': 848, 'платформы': 1112, 'языки': 2241, 'условные': 2012, 'обозначения': 876, 'технические': 1910, 'аналитические': 36, 'сложную': 1686, 'информацию': 513, 'определять': 965, 'функциональные': 2096, 'требования': 1957, 'спецификации': 1785, 'исследования': 534, 'обучения': 908, 'получать': 1182, 'например': 798, 'поиск': 1165, 'анализ': 33, 'документов': 335, 'разработка': 1495, 'проблемы': 1341, 'своевременно': 1629, 'идентифицировать': 444, 'решать': 1573, 'грамотно': 266, 'собирать': 1704, 'разрабатывать': 1491, 'альтернативы': 31, 'решений': 1576, 'выбирать': 205, 'наиболее': 791, 'варианты': 101, 'необходимое': 829, 'управления': 1999, 'выполнения': 218, 'требований': 1956, 'пользователя': 1188, 'систем': 1664, 'нормальных': 851, 'сценариев': 1867, 'соблюдения': 1708, 'стандартов': 1817, 'руководства': 1591, 'стилю': 1828, 'проектов': 1388, 'пользовательских': 1186, 'интерфейсов': 505, 'существующего': 1856, 'кода': 589, 'качестве': 570, 'основы': 997, 'выбора': 207, 'инструмента': 492, 'из': 445, 'имеющихся': 476, 'базами': 55, 'различными': 1475, 'обмена': 871, 'данными': 283, 'строить': 1844, 'сложной': 1684, 'устройствами': 2039, 'получения': 1183, 'устранение': 2034, 'распространенных': 1512, 'тщательного': 1973, 'тестирования': 1901, 'документирования': 333, 'испытаний': 531, 'планировать': 1106, 'тестирование': 1900, 'элементов': 2214, 'прове ...

# %%
print(count_vector.toarray().sum(axis=0))
# Out:
# [109 231  36 ...  29  67  28]

# %%
print(cv.stop_words)
# Out:
# ['как', 'от', 'его', 'или', 'and', '06', '10', '11', '12', '13', '14', '15', '17', '27', '28', 'для', 'при', 'по', 'на', 'их', 'он', 'за', '20', 'должен', 'специалист', 'понимать', 'знать', 'работа', 'это', 'работы']

# %%
print(cv.get_feature_names())
# Out:
# ['2d', '3d', '45', 'cad', 'cam', 'copyright', 'iso', 'microsoft', 'mvc', 'office', 'smart', 'аварийной', 'автоматизации', 'автоматизированного', 'автоматического', 'адаптироваться', 'аккуратном', 'аккуратности', 'аксессуарам', 'аксессуарами', 'аксессуаров', 'активно', 'активного', 'активности', 'актуальность', 'актуальные', 'актуальных', 'акты', 'алгоритм', 'алгоритмы', 'альтернативные', 'альтернативы', 'алюминия', 'анализ', 'анализа', 'анализировать', 'аналитические', 'аналитический', 'аналитического', 'анимации', 'аппаратами', 'аппаратные', 'аппаратных', 'архитекторов', 'архитектурной', 'архитектурных', 'архитектуру', 'архитектуры', 'аспектах', 'аспекты', 'ассортимент', 'атмосферы', 'аудиторией', 'аудитории', 'багажа', 'базами', 'базовые', 'базовых', 'базы', 'баланс', 'баланса', 'без', 'безопарный', 'безопасно', 'безопасного', 'безопасное', 'безопасной', 'безопасном', 'безопасность', 'безопасную', 'безопасные', 'безопасным', 'безопасных', 'библиотеки', 'бизнес', 'бизнеса', 'блоков', 'блюд', 'блюдам', 'более', 'болезни', 'болты', 'большинстве', 'ботанические', 'брожения', 'будет', 'будут', 'будущего', 'будущие', 'бумаги', 'бумажном', 'быстро', 'быстрого', 'быть', 'бюджет', 'бюджета', 'бюджетные', 'важность', 'важных', 'вариант', 'вариантов', 'варианты', 'ввод', 'ввода', 'вводить', 'веб', 'ведении', 'ведения', 'величин', 'вентиляции', 'вертикальной', 'вертикальных', 'вести', 'вещей', 'веществ', 'веществами', 'взаимодействие', 'взаимодействия', 'взаимоотношений', 'взаимосвязь', 'взвешенного', 'вид', 'вида', 'видам', 'видами', 'виде', 'видео', 'видов', 'виду', 'виды', 'визуализации', 'визуализировать', 'вина', 'винты', 'вклад', 'включая', 'вкус', 'вкуса', 'вкусовые', 'владеть', 'влияние', 'влияния', 'влияющих', 'вместе', 'внедрения', 'внедрять', 'внешнего', 'внешней', 'внешние', 'внешний', 'внешних', 'внимание', 'внимания', 'внимательно', 'вносить', 'внутренней', 'внутренние', 'внутренних', 'внутри', 'во', 'водных', 'водопроводных', 'воды', 'возгорания', 'воздействие', 'воздействия', 'воздействующие', 'возможностей', 'возможности', 'возможность', 'возможностями', 'возможные', 'возможных', 'возникающие', 'возникновении', 'возникновения', 'возникнуть', 'возникших', 'возраста', 'возрастных', 'вопросам', 'вопросов', 'вопросы', 'ворлдскиллс', 'восстанавливать', 'впечатление', 'впечатления', 'вредных', 'временем', 'времени', 'временные', 'временных', 'время', 'вручную', 'все', 'всего', 'всей', 'всем', 'всему', 'всех', 'вспомогательные', 'вспомогательных', 'встроенные', 'всю', 'въезда', 'выбирать', 'выбор', 'выбора', 'выбранные', 'выбранных', 'выбрать', 'выдвижения', 'выкладки', 'выпекания', 'выпечке', 'выпечки', 'выполнение', 'выполнении', 'выполнения', 'выполненной', 'выполненных', 'выполнить', 'выполняемой', 'выполнять', 'выпуск', 'выработки', 'выравнивания', 'высокие', 'высокого', 'высокой', 'высококачественного', 'высоком', 'высоте', 'высоты', 'выстраивания', 'выстраивать', 'вычисления', 'выявления', 'выявленных', 'выявлять', 'газа', 'гарантии', 'где', 'генерации', 'геометрии', 'геометрические', 'геометрию', 'гибки', 'гигиенические', 'гигиенических', 'гигиены', 'глаз', 'гневом', 'горизонтальных', 'горячего', 'гостей', 'гостем', 'гостя', 'гостями', 'готовить', 'готовности', 'готового', 'готовой', 'готовые', 'готовых', 'градусов', 'грамотно', 'график', 'графика', 'графике', 'графиков', 'графический', 'графических', 'графическую', 'групп', 'группам', 'группы', 'давать', 'давлением', 'дальнейшего', 'данной', 'данному', 'данные', 'данными', 'данных', 'датчики', 'датчиков', 'двигателей', 'движения', 'действие', 'действий', 'действия', 'действующие', 'действующих', 'декоративных', 'делать', 'деле', 'деловой', 'деловых', 'демонстрации', 'демонстрировать', 'дерево', 'деревянных', 'деталей', 'детали', 'деталям', 'дефектов', 'дефекты', 'деятельности', 'деятельность', 'диагностики', 'диагностические', 'диаграммы', 'диапазон', 'дизайн', 'дизайна', 'дизайне', 'дизайну', 'дизельных', 'динамического', 'динамической', 'длины', 'длительность', 'до' ...

# %%
tf_idf = pd.DataFrame(data = count_vector.toarray(), columns=cv.get_feature_names())

final_df = tf_idf

print("{} rows".format(final_df.shape[0]))
final_df.T.nlargest(8, 0)
# Out:
# 823 rows
#                 0    1    2    3    4    5    ...  817  818  819  820  821  822
# уметь             7    7    7    7    7    7  ...    0    0    0    0    0    0
# приложения        6    6    6    6    6    6  ...    0    0    0    0    0    0
# схемы             4    4    4    4    4    4  ...    0    0    0    0    0    0
# важность          3    3    3    3    3    3  ...    0    0    0    0    0    0
# использования     3    3    3    3    3    3  ...    5    5    5    5    5    5
# оптимизации       3    3    3    3    3    3  ...    0    0    0    0    0    0
# оптимизировать    3    3    3    3    3    3  ...    0    0    0    0    0    0
# приложений        3    3    3    3    3    3  ...    0    0    0    0    0    0
#
# [8 rows x 823 columns]

# %%
# K-Means
from sklearn import cluster

# %%
def run_KMeans(max_k, data):
    max_k += 1
    kmeans_results = dict()
    for k in range(2 , max_k):
        kmeans = cluster.KMeans(n_clusters = k
                               , init = 'k-means++'
                               , n_init = 10
                               , tol = 0.0001
                               , n_jobs = -1
                               , random_state = 1
                               , algorithm = 'full')

        kmeans_results.update( {k : kmeans.fit(data)} )
        
    return kmeans_results

# %%
def printAvg(avg_dict):
    for avg in sorted(avg_dict.keys(), reverse=True):
        print("Avg: {}\tK:{}".format(avg.round(4), avg_dict[avg]))
        
def plotSilhouette(df, n_clusters, kmeans_labels, silhouette_avg):
    fig, ax1 = plt.subplots(1)
    fig.set_size_inches(8, 6)
    ax1.set_xlim([-0.2, 1])
    ax1.set_ylim([0, len(df) + (n_clusters + 1) * 10])
    
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--") # The vertical line for average silhouette score of all the values
    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.2, 0, 0.2, 0.4, 0.6, 0.8, 1])
    plt.title(("Silhouette analysis for K = %d" % n_clusters), fontsize=10, fontweight='bold')
    
    y_lower = 10
    sample_silhouette_values = silhouette_samples(df, kmeans_labels) # Compute the silhouette scores for each sample
    for i in range(n_clusters):
        ith_cluster_silhouette_values = sample_silhouette_values[kmeans_labels == i]
        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / n_clusters)
        ax1.fill_betweenx(np.arange(y_lower, y_upper), 0, ith_cluster_silhouette_values, facecolor=color, edgecolor=color, alpha=0.7)

        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i)) # Label the silhouette plots with their cluster numbers at the middle
        y_lower = y_upper + 10  # Compute the new y_lower for next plot. 10 for the 0 samples
    plt.show()
    
        
def silhouette(kmeans_dict, df, plot=False):
    df = df.to_numpy()
    avg_dict = dict()
    for n_clusters, kmeans in kmeans_dict.items():      
        kmeans_labels = kmeans.predict(df)
        silhouette_avg = silhouette_score(df, kmeans_labels) # Average Score for all Samples
        avg_dict.update( {silhouette_avg : n_clusters} )
    
        if(plot): plotSilhouette(df, n_clusters, kmeans_labels, silhouette_avg)

# %%
# Visualization and Analysis
import matplotlib.pyplot  as plt
import matplotlib.cm      as cm
import seaborn            as sns
from sklearn.metrics                  import silhouette_samples, silhouette_score
from wordcloud                        import WordCloud

# %%
# Running Kmeans
k = 10
kmeans_results = run_KMeans(k, final_df)

# Plotting Silhouette Analysis
silhouette(kmeans_results, final_df, plot=True)

# %%
def get_top_features_cluster(tf_idf_array, prediction, n_feats):
    labels = np.unique(prediction)
    dfs = []
    for label in labels:
        id_temp = np.where(prediction==label) # indices for each cluster
        x_means = np.mean(tf_idf_array[id_temp], axis = 0) # returns average score across cluster
        sorted_means = np.argsort(x_means)[::-1][:n_feats] # indices with top 20 scores
        features = cv.get_feature_names()
        best_features = [(features[i], x_means[i]) for i in sorted_means]
        df = pd.DataFrame(best_features, columns = ['features', 'score'])
        dfs.append(df)
    return dfs

def plotWords(dfs, n_feats):
    plt.figure(figsize=(8, 4))
    for i in range(0, len(dfs)):
        plt.title(("Most Common Words in Cluster {}".format(i)), fontsize=10, fontweight='bold')
        sns.barplot(x = 'score' , y = 'features', orient = 'h' , data = dfs[i][:n_feats])
        plt.show()

# %%
best_result = 10 #5
kmeans = kmeans_results.get(best_result)

final_df_array = final_df.to_numpy()
prediction = kmeans.predict(final_df)
n_feats = 20
dfs = get_top_features_cluster(final_df_array, prediction, n_feats)
plotWords(dfs, 13)

# %%
# Transforms a centroids dataframe into a dictionary to be used on a WordCloud.
def centroidsDict(centroids, index):
    a = centroids.T[index].sort_values(ascending = False).reset_index().values
    centroid_dict = dict()

    for i in range(0, len(a)):
        centroid_dict.update( {a[i,0] : a[i,1]} )

    return centroid_dict

def generateWordClouds(centroids):
    wordcloud = WordCloud(max_font_size=100, background_color = 'white')
    for i in range(0, len(centroids)):
        centroid_dict = centroidsDict(centroids, i)        
        wordcloud.generate_from_frequencies(centroid_dict)

        plt.figure()
        plt.title('Cluster {}'.format(i))
        plt.imshow(wordcloud)
        plt.axis("off")
        plt.show()

# %%
centroids = pd.DataFrame(kmeans.cluster_centers_)
centroids.columns = final_df.columns
generateWordClouds(centroids)

# %%
labels = kmeans.labels_ 
data_with_clusters = np.array(new_dataset)
print(data_with_clusters.shape)
print(labels.shape)
data_with_clusters = np.column_stack((data_with_clusters, labels))
A=pd.DataFrame(data_with_clusters,columns=["компетения","описание компетенции", "группа навыков", "вес группы навыков", "описание группы навыков", "все группы навыков", "кластер"])
A.to_excel('data_with_cluster.xlsx')
# data['label'] = labels
# data.head()
# Out:
# (823, 6)
# (823,)
